# %% [markdown]
# # A program For Photographers Event

# %% [markdown]
# ## Introduction

# %% [markdown]
# ABC is a company based in Toronto for organizing events, currently it works on a project to organize an event for 5 days for a group of photographers from all over the world.The company has to put a good program, including a hotel of residence, a hall for meetings, places of landscape to visit, stores for shopping, restaurants and cafes. So the company’s purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ## Table of contents

# %% [markdown]
# ### 01- Import Libraries
# ### 02- Define Foursquare Credentials
# ### 03- Define the city and get its latitude & longitude
# ### 04- Search for Hotels & clean dataframe
# ### 05- Search for Parks & clean dataframe
# ### 06- Search for Restaurants & clean dataframe
# ### 07- Search for Cafeteria & clean dataframe
# ### 08- Search for Shopping Stores & clean dataframe
# ### 09- Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together
# ### 10- Generate map to visualize Park, Restaurant and Cafeteria and how they cluster togethe

# %% [markdown]
# ## Import Libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

# %% [markdown]
# ## Define Foursquare Credentials

# %%
ClIENT_ID = 'MKBS33KBHGHJVC1M0PW0RWACML2BFOZWGO2510DRO4WHPQSD' # your Foursquare ID
ClIENT_SECRET = 'US0VTVDIKKB253MYPLRG5KOITMAOGXQ2SRNYKL5B1HYQN05M' # your Foursquare Secret
VERSION = '20200525'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: MKBS33KBHGHJVC1M0PW0RWACML2BFOZWGO2510DRO4WHPQSD
# Foursquare_Secret:US0VTVDIKKB253MYPLRG5KOITMAOGXQ2SRNYKL5B1HYQN05M

# %% [markdown]
# ## Define the city and get its latitude & longitude

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %% [markdown]
# ## Search for Hotels

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MKBS33KBHGHJVC1M0PW0RWACML2BFOZWGO2510DRO4WHPQSD&client_secret=US0VTVDIKKB253MYPLRG5KOITMAOGXQ2SRNYKL5B1HYQN05M&ll=43.6534817,-79.3839347&v=20200525&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# C:\Users\Vivek\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                     name  \
# 0  51d212c3498ebf27dc469bc9                            Chelsea Hotel
# 1  4ab2d511f964a5209b6c20e3            Sheraton Centre Toronto Hotel
# 2  4ae61cf6f964a520caa421e3                     Pantages Hotel & Spa
# 3  51e48697498eded9073c6c17            Crew Room Eaton Chelsea Hotel
# 4  4ad4c05cf964a520bbf520e3  Cosmopolitan Toronto Centre Hotel & Spa
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590390527    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590390527    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590390527    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590390527    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590390527    False
#
#          location.address location.crossStreet  location.lat  location.lng  \
# 0  33 Gerrard Street West          at Yonge St     43.658498    -79.383097
# 1   123 Queen Street West          at York St.     43.650594    -79.384530
# 2         200 Victoria St         at Shuter St     43.654498    -79.379035
# 3  33 Gerrard Street West                  NaN     43.658094    -79.382711
# 4           8 Colborne St          at Yonge St     43.649064    -79.377598
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65849759157591...                562
# 1  [{'label': 'display', 'lat': 43.6505944, 'lng'...                324
# 2  [{'label': 'display', 'lat': 43.65449797039222...                410
# 3  [{'label': 'display', 'lat': 43.65809435580944...                522
# 4  [{'label': 'display', 'lat': 43.64906432957466...                708
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1Z4          CA       Toronto             ON
# 1             M5H 2M9          CA       Toronto             ON
# 2                 NaN          CA       Toronto             ON
# 3                 NaN          CA       Toronto             ON
# 4             M5E 1E1          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [33 Gerrard Street West (at Yonge St), Toronto...
# 1           Canada  [123 Queen Street West (at York St.), Toronto ...
# 2           Canada  [200 Victoria St (at Shuter St), Toronto ON, C...
# 3           Canada       [33 Gerrard Street West, Toronto ON, Canada]
# 4           Canada  [8 Colborne St (at Yonge St), Toronto ON M5E 1...
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4          NaN                   NaN

# %% [markdown]
# ## Clean Hotel Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                       name categories                 address  \
# 0                            Chelsea Hotel      Hotel  33 Gerrard Street West
# 1            Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West
# 2                     Pantages Hotel & Spa      Hotel         200 Victoria St
# 3            Crew Room Eaton Chelsea Hotel      Hotel  33 Gerrard Street West
# 4  Cosmopolitan Toronto Centre Hotel & Spa      Hotel           8 Colborne St
#
#     crossStreet        lat        lng  \
# 0   at Yonge St  43.658498 -79.383097
# 1   at York St.  43.650594 -79.384530
# 2  at Shuter St  43.654498 -79.379035
# 3           NaN  43.658094 -79.382711
# 4   at Yonge St  43.649064 -79.377598
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65849759157591...       562    M5G 1Z4  CA
# 1  [{'label': 'display', 'lat': 43.6505944, 'lng'...       324    M5H 2M9  CA
# 2  [{'label': 'display', 'lat': 43.65449797039222...       410        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65809435580944...       522        NaN  CA
# 4  [{'label': 'display', 'lat': 43.64906432957466...       708    M5E 1E1  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [33 Gerrard Street West (at Yonge St), Toronto...
# 1  Toronto    ON  Canada  [123 Queen Street West (at York St.), Toronto ...
# 2  Toronto    ON  Canada  [200 Victoria St (at Shuter St), Toronto ON, C...
# 3  Toronto    ON  Canada       [33 Gerrard Street West, Toronto ON, Canada]
# 4  Toronto    ON  Canada  [8 Colborne St (at Yonge St), Toronto ON M5E 1...
#
#   neighborhood                        id
# 0          NaN  51d212c3498ebf27dc469bc9
# 1          NaN  4ab2d511f964a5209b6c20e3
# 2          NaN  4ae61cf6f964a520caa421e3
# 3          NaN  51e48697498eded9073c6c17
# 4          NaN  4ad4c05cf964a520bbf520e3

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name  \
# 0                                    Chelsea Hotel
# 1                    Sheraton Centre Toronto Hotel
# 2                             Pantages Hotel & Spa
# 3                    Crew Room Eaton Chelsea Hotel
# 4          Cosmopolitan Toronto Centre Hotel & Spa
# 5                   The Rex Hotel Jazz & Blues Bar
# 6                  One King West Hotel & Residence
# 7                                   VFM Test Hotel
# 8   Sheraton Centre Toronto Hotel - Grand Ballroom
# 9                                  Stathcona Hotel
# 10               Sheraton Centre Hotel Club Lounge
# 11                                  Pentagos hotel
# 12              Henri's Bar at One King West hotel
# 13                               Be SixFifty Hotel
# 14                Shizen Spa at the Pantages Hotel
# 15                                       650 Hotel
# 16                              Pantages Hotel Gym
# 17                                  St Regis Hotel
# 18                   Pantages Hotel Toronto Centre
# 19                    Bond Place Hotel Parking Lot
# 20                      The Adelaide Hotel Toronto
# 21                   The Spa At The Adelaide Hotel
# 22         Smoldering remains of the Empress Hotel
# 23  Chelsea Hotel, Toronto Meetings & Events Venue
# 24           Suites at One King West Hotel Toronto
# 25                           89 Chestnut Residence
# 26                            DoubleTree by Hilton
# 27                                  Fitness Centre
# 28    Marriott Downtown at CF Toronto Eaton Centre
# 29                                          Bistro
#
#                                   categories                        address  \
# 0                                      Hotel         33 Gerrard Street West
# 1                                      Hotel          123 Queen Street West
# 2                                      Hotel                200 Victoria St
# 3                                      Hotel         33 Gerrard Street West
# 4                                      Hotel                  8 Colborne St
# 5                                  Jazz Club                 194 Queen St W
# 6                                      Hotel                    1 King St W
# 7                                      Hotel                 123 Test Drive
# 8                                   Ballroom          123 Queen Street West
# 9                                      Hotel                            NaN
# 10                                    Lounge                            NaN
# 11  Residential Building (Apartment / Condo)                            NaN
# 12                       American Restaurant                    1 King West
# 13                                     Hotel                 650 Bay Street
# 14                                       Spa                200 Victoria St
# 15                                     Hotel                 650 Bay Street
# 16                                       Gym               200 Victoria St.
# 17                                     Hotel                     325 Bay St
# 18  Residential Building (Apartment / Condo)            200 Victoria Street
# 19                        Miscellaneous Shop                Bond And Dundas
# 20                                     Hotel                     325 Bay St
# 21                                       Spa                     325 Bay St
# 22                                     Hotel                   335 Yonge St
# 23                         Convention Center         33 Gerrard Street West
# 24                                     Hotel  1 King St W Toronto ON Canada
# 25                    College Residence Hall                89 Chestnut St.
# 26                                     Hotel            108 Chestnut Street
# 27                                       Gym                    525 Bay St.
# 28                                     Hotel                 525 Bay Street
# 29                                Restaurant              1 king West hotel
#
#           lat        lng postalCode state
# 0   43.658498 -79.383097    M5G 1Z4    ON
# 1   43.650594 -79.384530    M5H 2M9    ON
# 2   43.654498 -79.379035        NaN    ON
# 3   43.658094 -79.382711        NaN    ON
# 4   43.649064 -79.377598    M5E 1E1    ON
# 5   43.650505 -79.388577    M5V 1Z1    ON
# 6   43.649139 -79.377876    M5H 1A1    ON
# 7   43.658434 -79.387894    M2M 2M2    ON
# 8   43.651200 -79.384520        NaN    ON
# 9   43.654947 -79.386359        NaN    ON
# 10  43.651063 -79.384527    M5H 2M9    ON
# 11  43.653976 -79.379875        NaN    ON
# 12  43.648945 -79.378028        NaN    ON
# 13  43.657120 -79.384560        NaN    ON
# 14  43.655198 -79.379913        NaN    ON
# 15  43.657046 -79.384411        NaN    ON
# 16  43.654464 -79.379036    M5B 1V8    ON
# 17  43.649770 -79.380701    M5H 4G3    ON
# 18  43.655205 -79.379182    M5B 1V8    ON
# 19  43.656224 -79.378830        NaN   NaN
# 20  43.649831 -79.380164    M5H 4G3    ON
# 21  43.649725 -79.380346    M5H 4G5    ON
# 22  43.657956 -79.381698        NaN    ON
# 23  43.658446 -79.382985    M5G 1Z4    ON
# 24  43.649077 -79.378468        NaN    ON
# 25  43.654160 -79.385291    M5G 1R1    ON
# 26  43.654608 -79.385942    M5G 1R3    ON
# 27  43.654690 -79.381739    M5G 2L2    ON
# 28  43.654728 -79.382422    M5G 2L2    ON
# 29  43.648961 -79.378069    M5H 1N1    ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                               name  \
# 0                                    Chelsea Hotel
# 1                    Sheraton Centre Toronto Hotel
# 4          Cosmopolitan Toronto Centre Hotel & Spa
# 5                   The Rex Hotel Jazz & Blues Bar
# 6                  One King West Hotel & Residence
# 7                                   VFM Test Hotel
# 16                              Pantages Hotel Gym
# 17                                  St Regis Hotel
# 18                   Pantages Hotel Toronto Centre
# 20                      The Adelaide Hotel Toronto
# 21                   The Spa At The Adelaide Hotel
# 23  Chelsea Hotel, Toronto Meetings & Events Venue
# 25                           89 Chestnut Residence
# 26                            DoubleTree by Hilton
# 27                                  Fitness Centre
# 28    Marriott Downtown at CF Toronto Eaton Centre
# 29                                          Bistro
#
#                                   categories                 address  \
# 0                                      Hotel  33 Gerrard Street West
# 1                                      Hotel   123 Queen Street West
# 4                                      Hotel           8 Colborne St
# 5                                  Jazz Club          194 Queen St W
# 6                                      Hotel             1 King St W
# 7                                      Hotel          123 Test Drive
# 16                                       Gym        200 Victoria St.
# 17                                     Hotel              325 Bay St
# 18  Residential Building (Apartment / Condo)     200 Victoria Street
# 20                                     Hotel              325 Bay St
# 21                                       Spa              325 Bay St
# 23                         Convention Center  33 Gerrard Street West
# 25                    College Residence Hall         89 Chestnut St.
# 26                                     Hotel     108 Chestnut Street
# 27                                       Gym             525 Bay St.
# 28                                     Hotel          525 Bay Street
# 29                                Restaurant       1 king West hotel
#
#           lat        lng postalCode state
# 0   43.658498 -79.383097    M5G 1Z4    ON
# 1   43.650594 -79.384530    M5H 2M9    ON
# 4   43.649064 -79.377598    M5E 1E1    ON
# 5   43.650505 -79.388577    M5V 1Z1    ON
# 6   43.649139 -79.377876    M5H 1A1    ON
# 7   43.658434 -79.387894    M2M 2M2    ON
# 16  43.654464 -79.379036    M5B 1V8    ON
# 17  43.649770 -79.380701    M5H 4G3    ON
# 18  43.655205 -79.379182    M5B 1V8    ON
# 20  43.649831 -79.380164    M5H 4G3    ON
# 21  43.649725 -79.380346    M5H 4G5    ON
# 23  43.658446 -79.382985    M5G 1Z4    ON
# 25  43.654160 -79.385291    M5G 1R1    ON
# 26  43.654608 -79.385942    M5G 1R3    ON
# 27  43.654690 -79.381739    M5G 2L2    ON
# 28  43.654728 -79.382422    M5G 2L2    ON
# 29  43.648961 -79.378069    M5H 1N1    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name categories  \
# 0                                  Chelsea Hotel      Hotel
# 1                  Sheraton Centre Toronto Hotel      Hotel
# 4        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 6                One King West Hotel & Residence      Hotel
# 7                                 VFM Test Hotel      Hotel
# 17                                St Regis Hotel      Hotel
# 20                    The Adelaide Hotel Toronto      Hotel
# 26                          DoubleTree by Hilton      Hotel
# 28  Marriott Downtown at CF Toronto Eaton Centre      Hotel
#
#                    address        lat        lng postalCode state
# 0   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 1    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 4            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 6              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 7           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 17              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 20              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 26     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 28          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name categories  \
# 0                                  Chelsea Hotel      Hotel
# 1                  Sheraton Centre Toronto Hotel      Hotel
# 4        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 6                One King West Hotel & Residence      Hotel
# 7                                 VFM Test Hotel      Hotel
# 17                                St Regis Hotel      Hotel
# 20                    The Adelaide Hotel Toronto      Hotel
# 26                          DoubleTree by Hilton      Hotel
# 28  Marriott Downtown at CF Toronto Eaton Centre      Hotel
#
#                    address        lat        lng postalCode state
# 0   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 1    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 4            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 6              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 7           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 17              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 20              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 26     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 28          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                             name categories                address        lat  \
# 1  Sheraton Centre Toronto Hotel      Hotel  123 Queen Street West  43.650594
#
#         lng postalCode state
# 1 -79.38453    M5H 2M9    ON

# %% [markdown]
# ## Search for Parks

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MKBS33KBHGHJVC1M0PW0RWACML2BFOZWGO2510DRO4WHPQSD&client_secret=US0VTVDIKKB253MYPLRG5KOITMAOGXQ2SRNYKL5B1HYQN05M&ll=43.6534817,-79.3839347&v=20200525&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
# C:\Users\Vivek\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                name  \
# 0  4b170e47f964a5208cc123e3         Queen's Park Subway Station
# 1  4b54deadf964a520a3d027e3                         Grange Park
# 2  4b9177e4f964a520d2be33e3  TTC Streetcar #403 - Victoria park
# 3  4ad80fcef964a520a61021e3                       One Park Lane
# 4  4bfc5019da7120a132df49fd   St. Andrews Playground / Dog Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...  v-1590390564    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1590390564    False
# 2  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...  v-1590390564    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1590390564    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1590390564    False
#
#            location.address      location.crossStreet  location.lat  \
# 0        691 University Ave             at College St     43.660006
# 1                       NaN                       NaN     43.652488
# 2                       NaN                       NaN     43.650735
# 3             280 Simcoe St        Dundas Street West     43.655442
# 4  450 Adelaide Street West  Brant St & Adelaide St W     43.647388
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.390272  [{'label': 'display', 'lat': 43.66000635700919...
# 1    -79.392053  [{'label': 'display', 'lat': 43.65248755299856...
# 2    -79.386921  [{'label': 'display', 'lat': 43.650735, 'lng':...
# 3    -79.390056  [{'label': 'display', 'lat': 43.65544241747622...
# 4    -79.398752  [{'label': 'display', 'lat': 43.64738759338116...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                887             M5G 2P1          CA       Toronto
# 1                663                 NaN          CA       Toronto
# 2                389                 NaN          CA       Toronto
# 3                539             M5T 2Y5          CA       Toronto
# 4               1372                 NaN          CA       Toronto
#
#   location.state location.country  \
# 0             ON           Canada
# 1             ON           Canada
# 2             ON           Canada
# 3             ON           Canada
# 4             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [691 University Ave (at College St), Toronto O...          NaN
# 1  [btwn College, University, Queen & Spadina, To...          NaN
# 2                               [Toronto ON, Canada]          NaN
# 3  [280 Simcoe St (Dundas Street West), Toronto O...          NaN
# 4  [450 Adelaide Street West (Brant St & Adelaide...          NaN

# %% [markdown]
# ## Clean Park Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                  name  \
# 0         Queen's Park Subway Station
# 1                         Grange Park
# 2  TTC Streetcar #403 - Victoria park
# 3                       One Park Lane
# 4   St. Andrews Playground / Dog Park
#
#                                  categories                   address  \
# 0                             Metro Station        691 University Ave
# 1                                      Park                       NaN
# 2                        Light Rail Station                       NaN
# 3  Residential Building (Apartment / Condo)             280 Simcoe St
# 4                                      Park  450 Adelaide Street West
#
#                 crossStreet        lat        lng  \
# 0             at College St  43.660006 -79.390272
# 1                       NaN  43.652488 -79.392053
# 2                       NaN  43.650735 -79.386921
# 3        Dundas Street West  43.655442 -79.390056
# 4  Brant St & Adelaide St W  43.647388 -79.398752
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...       887    M5G 2P1  CA
# 1  [{'label': 'display', 'lat': 43.65248755299856...       663        NaN  CA
# 2  [{'label': 'display', 'lat': 43.650735, 'lng':...       389        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65544241747622...       539    M5T 2Y5  CA
# 4  [{'label': 'display', 'lat': 43.64738759338116...      1372        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [691 University Ave (at College St), Toronto O...
# 1  Toronto    ON  Canada  [btwn College, University, Queen & Spadina, To...
# 2  Toronto    ON  Canada                               [Toronto ON, Canada]
# 3  Toronto    ON  Canada  [280 Simcoe St (Dundas Street West), Toronto O...
# 4  Toronto    ON  Canada  [450 Adelaide Street West (Brant St & Adelaide...
#
#                          id
# 0  4b170e47f964a5208cc123e3
# 1  4b54deadf964a520a3d027e3
# 2  4b9177e4f964a520d2be33e3
# 3  4ad80fcef964a520a61021e3
# 4  4bfc5019da7120a132df49fd

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                   name  \
# 0          Queen's Park Subway Station
# 1                          Grange Park
# 2   TTC Streetcar #403 - Victoria park
# 3                        One Park Lane
# 4    St. Andrews Playground / Dog Park
# 5               Physiomed College Park
# 6                          Berczy Park
# 7     Residences at College Park North
# 8                         Queen's Park
# 9        Crunch Fitness - College Park
# 10    Toothworks - College Park Dental
# 11                Clarence Square Park
# 12             Moss Park Tennis Courts
# 13              Trinity Bellwoods Park
# 14                     Winchester Park
# 15                 Tommy Thompson Park
# 16                 Riverdale Park West
# 17                   Barbara Hall Park
# 18                         Regent Park
# 19                            HTO Park
# 20             Stanley Park (Dog Park)
# 21              Parliament Square Park
# 22                   Barbara Hall Park
# 23        Regent Park Community Centre
# 24             St Lawrence on the Park
# 25                 Riverdale Park East
# 26             Cawthra Square Dog Park
# 27             Park Hyatt Bridal Suite
# 28                        Wilfrid Park
# 29                   Larry Sefton Park
#
#                                   categories                   address  \
# 0                              Metro Station        691 University Ave
# 1                                       Park                       NaN
# 2                         Light Rail Station                       NaN
# 3   Residential Building (Apartment / Condo)             280 Simcoe St
# 4                                       Park  450 Adelaide Street West
# 5                             Medical Center              382 Yonge St
# 6                                       Park    35 Wellington St. East
# 7   Residential Building (Apartment / Condo)               763 Bay St.
# 8                                       Park           University Ave.
# 9                       Gym / Fitness Center          382 Yonge Street
# 10                          Dentist's Office    444 Yonge St, Unit M16
# 11                                      Park               Spadina Ave
# 12                              Tennis Court                 Moss Park
# 13                                      Park        1053 Dundas St. W.
# 14                                Playground        530 Ontario Street
# 15                                      Park                 Leslie St
# 16                                      Park           500 Gerrard St.
# 17                                      Park         519 Church Street
# 18                              Neighborhood                       NaN
# 19                                      Park              Queen's Quay
# 20                                   Dog Run          King Street West
# 21                                      Park      44 Parliament Street
# 22                                      Park             519 Church St
# 23                          Community Center           465 Dundas St E
# 24                                  Building           65 Scadding Ave
# 25                                      Park         550 Broadview Ave
# 26                                   Dog Run            519 Church St.
# 27                                     Hotel               4 Avenue Rd
# 28                                    Office                       NaN
# 29                                     Plaza                       NaN
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.650735 -79.386921        NaN    ON
# 3   43.655442 -79.390056    M5T 2Y5    ON
# 4   43.647388 -79.398752        NaN    ON
# 5   43.659240 -79.382860    M5B 1S8    ON
# 6   43.648048 -79.375172        NaN    ON
# 7   43.659822 -79.385159    M5G 2R3    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 9   43.659263 -79.382632    M5G 1S8    ON
# 10  43.660009 -79.383905        NaN    ON
# 11  43.644222 -79.394230        NaN    ON
# 12  43.655337 -79.371923        NaN    ON
# 13  43.647072 -79.413756    M5H 2N2    ON
# 14  43.666231 -79.371631        NaN    ON
# 15  43.634180 -79.323671        NaN    ON
# 16  43.666048 -79.360941    M5A 2H3    ON
# 17  43.666728 -79.381084        NaN    ON
# 18  43.660009 -79.364191        NaN    ON
# 19  43.637949 -79.387820        NaN    ON
# 20  43.641668 -79.409269        NaN    ON
# 21  43.650264 -79.362195        NaN    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 23  43.659512 -79.363048    M5A 2B2    ON
# 24  43.648963 -79.364868        NaN    ON
# 25  43.669951 -79.355493    M4K 2P1    ON
# 26  43.666583 -79.380040        NaN    ON
# 27  43.668849 -79.394460        NaN    ON
# 28  43.650999 -79.364915        NaN   NaN
# 29  43.654589 -79.383405        NaN   NaN

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                 name  \
# 0        Queen's Park Subway Station
# 3                      One Park Lane
# 5             Physiomed College Park
# 7   Residences at College Park North
# 8                       Queen's Park
# 9      Crunch Fitness - College Park
# 13            Trinity Bellwoods Park
# 16               Riverdale Park West
# 22                 Barbara Hall Park
# 23      Regent Park Community Centre
# 25               Riverdale Park East
#
#                                   categories             address        lat  \
# 0                              Metro Station  691 University Ave  43.660006
# 3   Residential Building (Apartment / Condo)       280 Simcoe St  43.655442
# 5                             Medical Center        382 Yonge St  43.659240
# 7   Residential Building (Apartment / Condo)         763 Bay St.  43.659822
# 8                                       Park     University Ave.  43.663946
# 9                       Gym / Fitness Center    382 Yonge Street  43.659263
# 13                                      Park  1053 Dundas St. W.  43.647072
# 16                                      Park     500 Gerrard St.  43.666048
# 22                                      Park       519 Church St  43.666879
# 23                          Community Center     465 Dundas St E  43.659512
# 25                                      Park   550 Broadview Ave  43.669951
#
#           lng postalCode state
# 0  -79.390272    M5G 2P1    ON
# 3  -79.390056    M5T 2Y5    ON
# 5  -79.382860    M5B 1S8    ON
# 7  -79.385159    M5G 2R3    ON
# 8  -79.392180    M5R 2E8    ON
# 9  -79.382632    M5G 1S8    ON
# 13 -79.413756    M5H 2N2    ON
# 16 -79.360941    M5A 2H3    ON
# 22 -79.381068    M4Y 2K9    ON
# 23 -79.363048    M5A 2B2    ON
# 25 -79.355493    M4K 2P1    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories             address        lat  \
# 8             Queen's Park       Park     University Ave.  43.663946
# 13  Trinity Bellwoods Park       Park  1053 Dundas St. W.  43.647072
# 16     Riverdale Park West       Park     500 Gerrard St.  43.666048
# 22       Barbara Hall Park       Park       519 Church St  43.666879
# 25     Riverdale Park East       Park   550 Broadview Ave  43.669951
#
#           lng postalCode state
# 8  -79.392180    M5R 2E8    ON
# 13 -79.413756    M5H 2N2    ON
# 16 -79.360941    M5A 2H3    ON
# 22 -79.381068    M4Y 2K9    ON
# 25 -79.355493    M4K 2P1    ON

# %% [markdown]
# ## Search for Restaurants

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MKBS33KBHGHJVC1M0PW0RWACML2BFOZWGO2510DRO4WHPQSD&client_secret=US0VTVDIKKB253MYPLRG5KOITMAOGXQ2SRNYKL5B1HYQN05M&ll=43.6534817,-79.3839347&v=20200525&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
# C:\Users\Vivek\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                name  \
# 0  4ad4c05ff964a52048f720e3     Hemispheres Restaurant & Bistro
# 1  5750b013498e755287c6de97  Some Time BBQ Grill Restaurant 碳烤屋
# 2  4ad4c05cf964a52006f620e3               Victoria's Restaurant
# 3  4ad4c060f964a5207ff720e3              Rol San Restaurant 龍笙棧
# 4  4bd47e6fcfa7b7139f2924da                   Studio Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1590390583    False
# 1  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...  v-1590390583    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1590390583    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1590390583    False
# 4  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1590390583    False
#
#       location.address  location.lat  location.lng  \
# 0  110 Chestnut Street     43.654884    -79.385931
# 1   988 Baldwin Street     43.655874    -79.393826
# 2  37 King Street East     43.649298    -79.376431
# 3     323 Spadina Ave.     43.654318    -79.398650
# 4       389 Church St.     43.661500    -79.379319
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                224
# 1  [{'label': 'display', 'lat': 43.655874, 'lng':...                839
# 2  [{'label': 'display', 'lat': 43.64929834396347...                763
# 3  [{'label': 'display', 'lat': 43.65431754076345...               1188
# 4  [{'label': 'display', 'lat': 43.66150015906530...                966
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1                 NaN          CA       Toronto             ON
# 2             M5C 1E9          CA       Toronto             ON
# 3             M5T 2E9          CA       Toronto             ON
# 4                 M5B          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada           [988 Baldwin Street, Toronto ON, Canada]
# 2           Canada  [37 King Street East (at Le Meridien King Edwa...
# 3           Canada  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4           Canada  [389 Church St. (at Carlton St.), Toronto ON M...
#
#                location.crossStreet venuePage.id location.neighborhood
# 0                               NaN          NaN                   NaN
# 1                               NaN          NaN                   NaN
# 2  at Le Meridien King Edward Hotel    498556908                   NaN
# 3                     at D'Arcy St.          NaN     Kensington Market
# 4                    at Carlton St.          NaN                   NaN

# %% [markdown]
# ## Clean Restaurant Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0     Hemispheres Restaurant & Bistro  American Restaurant
# 1  Some Time BBQ Grill Restaurant 碳烤屋  Szechuan Restaurant
# 2               Victoria's Restaurant           Restaurant
# 3              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 4                   Studio Restaurant       Breakfast Spot
#
#                address        lat        lng  \
# 0  110 Chestnut Street  43.654884 -79.385931
# 1   988 Baldwin Street  43.655874 -79.393826
# 2  37 King Street East  43.649298 -79.376431
# 3     323 Spadina Ave.  43.654318 -79.398650
# 4       389 Church St.  43.661500 -79.379319
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...       224    M5G 1R3  CA
# 1  [{'label': 'display', 'lat': 43.655874, 'lng':...       839        NaN  CA
# 2  [{'label': 'display', 'lat': 43.64929834396347...       763    M5C 1E9  CA
# 3  [{'label': 'display', 'lat': 43.65431754076345...      1188    M5T 2E9  CA
# 4  [{'label': 'display', 'lat': 43.66150015906530...       966        M5B  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  Toronto    ON  Canada           [988 Baldwin Street, Toronto ON, Canada]
# 2  Toronto    ON  Canada  [37 King Street East (at Le Meridien King Edwa...
# 3  Toronto    ON  Canada  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4  Toronto    ON  Canada  [389 Church St. (at Carlton St.), Toronto ON M...
#
#                         crossStreet       neighborhood  \
# 0                               NaN                NaN
# 1                               NaN                NaN
# 2  at Le Meridien King Edward Hotel                NaN
# 3                     at D'Arcy St.  Kensington Market
# 4                    at Carlton St.                NaN
#
#                          id
# 0  4ad4c05ff964a52048f720e3
# 1  5750b013498e755287c6de97
# 2  4ad4c05cf964a52006f620e3
# 3  4ad4c060f964a5207ff720e3
# 4  4bd47e6fcfa7b7139f2924da

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                        name               categories  \
# 0           Hemispheres Restaurant & Bistro      American Restaurant
# 1        Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 2                     Victoria's Restaurant               Restaurant
# 3                    Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 4                         Studio Restaurant           Breakfast Spot
# 5                   Victor Restaurant & Bar                      Bar
# 6                  New Sky Restaurant 小沙田食家       Chinese Restaurant
# 7                   Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 8        North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 9                    Azure Restaurant & Bar               Restaurant
# 10            Green Tea Restaurant Downtown       Chinese Restaurant
# 11             Aroma Fine Indian Restaurant        Indian Restaurant
# 12              Cottage Restaurant & Lounge          Thai Restaurant
# 13           Goldstone Noodle Restaurant 金石             Noodle House
# 14  Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 15           The Hot House Restaurant & Bar      American Restaurant
# 16                    Sightlines Restaurant      American Restaurant
# 17                           360 Restaurant                 Wine Bar
# 18        Kensington Cornerstone Restaurant           Breakfast Spot
# 19                 Ka Chi Korean Restaurant        Korean Restaurant
# 20                    Restaurant | Adelaide               Restaurant
# 21                        Arriba Restaurant               Restaurant
# 22            Micheal's Restaurant and Deli                      Bar
# 23       Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 24                  The Lakeview Restaurant                    Diner
# 25            Hong Shing Chinese Restaurant       Chinese Restaurant
# 26               Alio Restaurant & Wine Bar       Italian Restaurant
# 27                  Osgoode Hall Restaurant  New American Restaurant
# 28               Matisse Restaurant And Bar               Restaurant
# 29                    ONE Restaurant/Lounge  New American Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 2               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 4                    389 Church St.  43.661500 -79.379319        M5B    ON
# 5                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 6                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 7                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 8                    476 Dundas St.  43.653185 -79.396677        NaN    ON
# 9                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 10  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 11                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 12                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 13                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 14                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 15                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 16                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 17                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 18               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 19                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 20          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 21                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 22                   566 Queen St W  43.647289 -79.403493        NaN    ON
# 23                 280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 24                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 25                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 26                  108 Dundas St W  43.655655 -79.384124    M5G 1C3    ON
# 27                   130 Queen St W  43.651979 -79.385049    M5H 2N6   NaN
# 28                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 29                116 Yorkville Ave  43.670809 -79.393272        NaN    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                        name            categories  \
# 0           Hemispheres Restaurant & Bistro   American Restaurant
# 2                     Victoria's Restaurant            Restaurant
# 3                    Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 4                         Studio Restaurant        Breakfast Spot
# 5                   Victor Restaurant & Bar                   Bar
# 6                  New Sky Restaurant 小沙田食家    Chinese Restaurant
# 7                   Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 9                    Azure Restaurant & Bar            Restaurant
# 10            Green Tea Restaurant Downtown    Chinese Restaurant
# 11             Aroma Fine Indian Restaurant     Indian Restaurant
# 12              Cottage Restaurant & Lounge       Thai Restaurant
# 13           Goldstone Noodle Restaurant 金石          Noodle House
# 14  Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 15           The Hot House Restaurant & Bar   American Restaurant
# 17                           360 Restaurant              Wine Bar
# 18        Kensington Cornerstone Restaurant        Breakfast Spot
# 19                 Ka Chi Korean Restaurant     Korean Restaurant
# 20                    Restaurant | Adelaide            Restaurant
# 21                        Arriba Restaurant            Restaurant
# 24                  The Lakeview Restaurant                 Diner
# 25            Hong Shing Chinese Restaurant    Chinese Restaurant
# 26               Alio Restaurant & Wine Bar    Italian Restaurant
# 28               Matisse Restaurant And Bar            Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 2               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 4                    389 Church St.  43.661500 -79.379319        M5B    ON
# 5                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 6                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 7                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 9                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 10  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 11                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 12                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 13                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 14                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 15                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 17                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 18               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 19                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 20          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 21                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 24                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 25                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 26                  108 Dundas St W  43.655655 -79.384124    M5G 1C3    ON
# 28                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON

# %% [markdown]
# ## Search for Cafeteria

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MKBS33KBHGHJVC1M0PW0RWACML2BFOZWGO2510DRO4WHPQSD&client_secret=US0VTVDIKKB253MYPLRG5KOITMAOGXQ2SRNYKL5B1HYQN05M&ll=43.6534817,-79.3839347&v=20200525&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
# C:\Users\Vivek\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                           name  \
# 0  4f9165bde4b04fef0087e4e2                      Cafeteria
# 1  528e99a211d262edc3708a6f              Stay Cafeteria 慢走
# 2  4b57256bf964a520332828e3                Sears Cafeteria
# 3  53bd6dfe498e6c1d3bc9333e  Industrial Alliance Cafeteria
# 4  524f1c8f498e983dde61ada0        Chestnut Tree Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1590390597    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1590390597    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1590390597    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1590390597    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1590390597    False
#
#                             location.address  location.lat  location.lng  \
# 0  The Hospital for Sick Children (SickKids)     43.657209    -79.386063
# 1                            388 Spadina Ave     43.655454    -79.399163
# 2                                      Yonge     43.656038    -79.380672
# 3                                        NaN     43.655657    -79.389443
# 4                         89 Chestnut Street     43.648231    -79.384045
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...                448
# 1  [{'label': 'display', 'lat': 43.65545427446646...               1246
# 2  [{'label': 'display', 'lat': 43.65603785909391...                387
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...                505
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...                584
#
#   location.cc location.city location.state location.country  \
# 0          CA       Toronto             ON           Canada
# 1          CA       Toronto             ON           Canada
# 2          CA       Toronto             ON           Canada
# 3          CA       Toronto             ON           Canada
# 4          CA       Toronto             ON           Canada
#
#                            location.formattedAddress location.crossStreet  \
# 0  [The Hospital for Sick Children (SickKids), To...                  NaN
# 1  [388 Spadina Ave (at Nassau St), Toronto ON M5...         at Nassau St
# 2               [Yonge (Dundas), Toronto ON, Canada]               Dundas
# 3                               [Toronto ON, Canada]                  NaN
# 4           [89 Chestnut Street, Toronto ON, Canada]                  NaN
#
#   location.postalCode
# 0                 NaN
# 1             M5T 2G5
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# ## Clean Cafeteria Dataframe¶

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                Sears Cafeteria            Food Court
# 3  Industrial Alliance Cafeteria             Cafeteria
# 4        Chestnut Tree Cafeteria             Cafeteria
#
#                                      address        lat        lng  \
# 0  The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                            388 Spadina Ave  43.655454 -79.399163
# 2                                      Yonge  43.656038 -79.380672
# 3                                        NaN  43.655657 -79.389443
# 4                         89 Chestnut Street  43.648231 -79.384045
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...       448  CA  Toronto
# 1  [{'label': 'display', 'lat': 43.65545427446646...      1246  CA  Toronto
# 2  [{'label': 'display', 'lat': 43.65603785909391...       387  CA  Toronto
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...       505  CA  Toronto
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...       584  CA  Toronto
#
#   state country                                   formattedAddress  \
# 0    ON  Canada  [The Hospital for Sick Children (SickKids), To...
# 1    ON  Canada  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2    ON  Canada               [Yonge (Dundas), Toronto ON, Canada]
# 3    ON  Canada                               [Toronto ON, Canada]
# 4    ON  Canada           [89 Chestnut Street, Toronto ON, Canada]
#
#     crossStreet postalCode                        id
# 0           NaN        NaN  4f9165bde4b04fef0087e4e2
# 1  at Nassau St    M5T 2G5  528e99a211d262edc3708a6f
# 2        Dundas        NaN  4b57256bf964a520332828e3
# 3           NaN        NaN  53bd6dfe498e6c1d3bc9333e
# 4           NaN        NaN  524f1c8f498e983dde61ada0

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                         Sears Cafeteria            Food Court
# 3           Industrial Alliance Cafeteria             Cafeteria
# 4                 Chestnut Tree Cafeteria             Cafeteria
# 5                          OCAD Cafeteria     College Cafeteria
# 6                         Dears Cafeteria          Dessert Shop
# 7                   Ryerson Hub Cafeteria     College Cafeteria
# 8                      SickKids Cafeteria            Food Court
# 9           De La Salle College Cafeteria     College Cafeteria
# 10                      Med Sci Cafeteria     College Cafeteria
# 11              Macdonald Block Cafeteria             Cafeteria
# 12                      Robarts Cafeteria     College Cafeteria
# 13                          OMP Cafeteria             Cafeteria
# 14                       Rogers Cafeteria            Food Court
# 15                      Choices Cafeteria            Food Court
# 16    Cafeteria, Lawrence Park Collegiate           High School
# 17    Cafeteria, Lawrence Park Collegiate           Event Space
# 18                       Kasala Cafeteria    African Restaurant
# 19                             Marketeria            Restaurant
# 20               Estonian House Cafeteria                  Café
# 21                                The Hub     College Cafeteria
# 22                           CC Cafeteria     College Cafeteria
# 23                             Radio Cafe            Food Court
# 24                          Innis College        Student Center
# 25     Lawrence Park Collegiate Cafeteria           High School
# 26                           L5 Cafeteria      Cuban Restaurant
# 27  6th Floor Cafeteria 12 Concorde Place                  Café
# 28          Westpark Healthcare Cafeteria                  Café
# 29                      Glendon Cafeteria     College Cafeteria
#
#                                       address        lat        lng state  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063    ON
# 1                             388 Spadina Ave  43.655454 -79.399163    ON
# 2                                       Yonge  43.656038 -79.380672    ON
# 3                                         NaN  43.655657 -79.389443    ON
# 4                          89 Chestnut Street  43.648231 -79.384045    ON
# 5                              100 McCaul St.  43.652780 -79.391762    ON
# 6                                         NaN  43.654179 -79.392555   NaN
# 7                            350 Victoria St.  43.658475 -79.377653    ON
# 8                       555 University Avenue  43.657584 -79.375652    ON
# 9                          131 Farnham Avenue  43.683003 -79.397815    ON
# 10                                        NaN  43.660260 -79.392977    ON
# 11                                        NaN  43.663212 -79.388062   NaN
# 12                         130 St. George St.  43.664864 -79.399766    ON
# 13                           1 Mount Pleasant  43.669801 -79.379790    ON
# 14                                        NaN  43.669904 -79.379748    ON
# 15                         200 Bloor Street E  43.671411 -79.381849    ON
# 16                                        NaN  43.721732 -79.409600   NaN
# 17                                        NaN  43.723286 -79.412222   NaN
# 18                                      Bloor  43.660759 -79.424018   NaN
# 19                                30 Bond St.  43.653585 -79.378843    ON
# 20                       958 Broadview avenue  43.681763 -79.358246    ON
# 21                           350 Victoria St.  43.658585 -79.380622    ON
# 22                             951 Carlaw Ave  43.684631 -79.348862    ON
# 23                          333 Bloor st east  43.671696 -79.380617    ON
# 24                               2 Sussex Ave  43.665556 -79.399298    ON
# 25                                        NaN  43.722757 -79.413734    ON
# 26                                        NaN  43.723019 -79.345012   NaN
# 27                          12 Concorde Place  43.721861 -79.329339    ON
# 28                          82 Buttonwood Ave  43.687714 -79.508885    ON
# 29                           2275 Bayview Ave  43.727383 -79.378080    ON
#
#    postalCode
# 0         NaN
# 1     M5T 2G5
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     M4V 1H7
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19    M5B 1W8
# 20        NaN
# 21    M5B 2K3
# 22        NaN
# 23        NaN
# 24    M5S 1J5
# 25        NaN
# 26        NaN
# 27    m3c 3k7
# 28        NaN
# 29        NaN

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 9           De La Salle College Cafeteria  College Cafeteria
# 19                             Marketeria         Restaurant
# 21                                The Hub  College Cafeteria
# 24                          Innis College     Student Center
# 27  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng state postalCode
# 1      388 Spadina Ave  43.655454 -79.399163    ON    M5T 2G5
# 9   131 Farnham Avenue  43.683003 -79.397815    ON    M4V 1H7
# 19         30 Bond St.  43.653585 -79.378843    ON    M5B 1W8
# 21    350 Victoria St.  43.658585 -79.380622    ON    M5B 2K3
# 24        2 Sussex Ave  43.665556 -79.399298    ON    M5S 1J5
# 27   12 Concorde Place  43.721861 -79.329339    ON    m3c 3k7

# %% [markdown]
# ## Search for Shopping Stores

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MKBS33KBHGHJVC1M0PW0RWACML2BFOZWGO2510DRO4WHPQSD&client_secret=US0VTVDIKKB253MYPLRG5KOITMAOGXQ2SRNYKL5B1HYQN05M&ll=43.6534817,-79.3839347&v=20200525&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
# C:\Users\Vivek\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                        name  \
# 0  5840cafe06f1a34af80cc609  Saks Fifth Avenue Club - Personal Shopping
# 1  4b9e86dff964a520e6eb36e3                TD Centre Shopping Concourse
# 2  4ad77a12f964a520260b21e3                     CF Toronto Eaton Centre
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...  v-1590390608    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1590390608    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1590390608    False
#
#      location.address location.crossStreet  location.lat  location.lng  \
# 0    176 Yonge Street    Queen Street West     43.651810    -79.379192
# 1  66 Wellington St W    btw York & Bay St     43.647184    -79.380932
# 2        220 Yonge St  btwn Queen & Dundas     43.654540    -79.380677
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...                424
# 1  [{'label': 'display', 'lat': 43.64718424611984...                741
# 2                                                NaN                287
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5C 2L7          CA       Toronto             ON
# 1             M5K 1A1          CA       Toronto             ON
# 2             M5B 2H1          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [176 Yonge Street (Queen Street West), Toronto...
# 1           Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 2           Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
#
#            location.neighborhood
# 0                            NaN
# 1                            NaN
# 2  Downtown Toronto, Toronto, ON

# %% [markdown]
# ## Clean Shopping Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
#
#               address          crossStreet        lat        lng  \
# 0    176 Yonge Street    Queen Street West  43.651810 -79.379192
# 1  66 Wellington St W    btw York & Bay St  43.647184 -79.380932
# 2        220 Yonge St  btwn Queen & Dundas  43.654540 -79.380677
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...       424    M5C 2L7  CA
# 1  [{'label': 'display', 'lat': 43.64718424611984...       741    M5K 1A1  CA
# 2                                                NaN       287    M5B 2H1  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [176 Yonge Street (Queen Street West), Toronto...
# 1  Toronto    ON  Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 2  Toronto    ON  Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
#
#                     neighborhood                        id
# 0                            NaN  5840cafe06f1a34af80cc609
# 1                            NaN  4b9e86dff964a520e6eb36e3
# 2  Downtown Toronto, Toronto, ON  4ad77a12f964a520260b21e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
#
#               address        lat        lng postalCode state
# 0    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 1  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 2        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 1  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
# 2       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
#
#          lng postalCode state
# 1 -79.380932    M5K 1A1    ON
# 2 -79.380677    M5B 2H1    ON

# %% [markdown]
# ## Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                     name         categories  \
# 0          Sheraton Centre Toronto Hotel              Hotel
# 1                      Stay Cafeteria 慢走   Asian Restaurant
# 2          De La Salle College Cafeteria  College Cafeteria
# 3                             Marketeria         Restaurant
# 4                                The Hub  College Cafeteria
# 5                          Innis College     Student Center
# 6  6th Floor Cafeteria 12 Concorde Place               Café
# 7           TD Centre Shopping Concourse      Shopping Mall
# 8                CF Toronto Eaton Centre      Shopping Mall
#
#                  address        lat        lng postalCode state
# 0  123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1        388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 2     131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 3            30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 4       350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 5           2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 6      12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 7     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 8           220 Yonge St  43.654540 -79.380677    M5B 2H1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                        name            categories  \
# 0                              Queen's Park                  Park
# 1                    Trinity Bellwoods Park                  Park
# 2                       Riverdale Park West                  Park
# 3                         Barbara Hall Park                  Park
# 4                       Riverdale Park East                  Park
# 5           Hemispheres Restaurant & Bistro   American Restaurant
# 6                     Victoria's Restaurant            Restaurant
# 7                    Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 8                         Studio Restaurant        Breakfast Spot
# 9                   Victor Restaurant & Bar                   Bar
# 10                 New Sky Restaurant 小沙田食家    Chinese Restaurant
# 11                  Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 12                   Azure Restaurant & Bar            Restaurant
# 13            Green Tea Restaurant Downtown    Chinese Restaurant
# 14             Aroma Fine Indian Restaurant     Indian Restaurant
# 15              Cottage Restaurant & Lounge       Thai Restaurant
# 16           Goldstone Noodle Restaurant 金石          Noodle House
# 17  Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 18           The Hot House Restaurant & Bar   American Restaurant
# 19                           360 Restaurant              Wine Bar
# 20        Kensington Cornerstone Restaurant        Breakfast Spot
# 21                 Ka Chi Korean Restaurant     Korean Restaurant
# 22                    Restaurant | Adelaide            Restaurant
# 23                        Arriba Restaurant            Restaurant
# 24                  The Lakeview Restaurant                 Diner
# 25            Hong Shing Chinese Restaurant    Chinese Restaurant
# 26               Alio Restaurant & Wine Bar    Italian Restaurant
# 27               Matisse Restaurant And Bar            Restaurant
# 28                        Stay Cafeteria 慢走      Asian Restaurant
# 29            De La Salle College Cafeteria     College Cafeteria
# 30                               Marketeria            Restaurant
# 31                                  The Hub     College Cafeteria
# 32                            Innis College        Student Center
# 33    6th Floor Cafeteria 12 Concorde Place                  Café
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 2                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 3                     519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 4                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 5               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 6               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 7                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 8                    389 Church St.  43.661500 -79.379319        M5B    ON
# 9                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 10                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 11                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 12                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 13  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 14                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 15                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 16                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 17                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 18                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 19                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 20               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 21                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 22          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 23                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 24                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 25                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 26                  108 Dundas St W  43.655655 -79.384124    M5G 1C3    ON
# 27                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 28                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 29               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 30                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 31                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 32                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 33                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
